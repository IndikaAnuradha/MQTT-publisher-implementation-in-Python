# %%
pip install paho-mqtt
# Out:
# ...
#      ---------------------------------------- 99.4/99.4 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.6.1-py3-none-any.whl size=65434 sha256=c3b98f81318d43cf7accf77e2edcace0176ccadbfe7291cfa811ab0cdae10ff9
#   Stored in directory: c:\users\indikab\appdata\local\pip\cache\wheels\0f\90\29\db29bb8ddc98ec5f2363b959130c9ddbcf5cfdb4a00b6184dd
# Successfully built paho-mqtt
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 22.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.1
#     Uninstalling pip-23.1.1:
#       Successfully uninstalled pip-23.1.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install paho-mqtt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import time

from paho.mqtt import client as mqtt_client

broker = 'broker.mqttdashboard.com'
port = 1883
topic = "Building/Temperature"
# generate client ID with pub prefix randomly
client_id = f'python-mqtt-{random.randint(0, 1000)}'
username = 'websocket'
password = 'public1'

def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n" % rc)

    client = mqtt_client.Client(client_id)
    client.username_pw_set(username, password)
    client.on_connect = on_connect
    client.connect(broker, port)
    return client

def publish(client, num_messages):
    msg_count = 0
    while msg_count < num_messages:
        time.sleep(1)
        msg = f"messages: {msg_count}"
        result = client.publish(topic, msg)
        # result: [0, 1]
        status = result[0]
        if status == 0:
            print(f"Send `{msg}` to topic `{topic}`")
        else:
            print(f"Failed to send message to topic {topic}")
        msg_count += 1

def run():
    num_messages = 6  # Change this to the desired number of messages
    client = connect_mqtt()
    client.loop_start()
    publish(client, num_messages)

if __name__ == '__main__':
    run()
# Out:
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Send `messages: 0` to topic `Building/Temperature`
# Send `messages: 1` to topic `Building/Temperature`
# Connected to MQTT Broker!
# Send `messages: 2` to topic `Building/Temperature`
# Send `messages: 3` to topic `Building/Temperature`
# Send `messages: 4` to topic `Building/Temperature`
# Connected to MQTT Broker!
# Send `messages: 5` to topic `Building/Temperature`
# Connected to MQTT Broker!
# Connected to MQTT Broker!

# %%
import random
import time

from paho.mqtt import client as mqtt_client

broker = 'broker.mqttdashboard.com'
port = 1883
topic = "Building/Temperature"
# generate client ID with pub prefix randomly
client_id = f'python-mqtt-{random.randint(0, 1000)}'
username = 'emqx'
password = 'staysafe'

def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n" % rc)

    client = mqtt_client.Client(client_id)
    client.username_pw_set(username, password)
    client.on_connect = on_connect
    client.connect(broker, port)
    return client


def publish_temperature(client, num_messages):
    msg_count = 0
    while msg_count < num_messages:
        time.sleep(1)
        # Generate synthetic temperature data between 0°C and 40°C
        temperature = round(random.uniform(0, 40), 2)
        msg = f"Temperature: {temperature}°C"
        result = client.publish(topic, msg)
        status = result[0]
        if status == 0:
            print(f"Sent: {msg}")
        else:
            print(f"Failed to send message")
        msg_count += 1


def run():
    num_temperature_readings = 5  # Change this to the desired number of readings
    client = connect_mqtt()
    client.loop_start()
    publish_temperature(client, num_temperature_readings)


if __name__ == '__main__':
    run()
# Out:
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Sent: Temperature: 12.67°C
# Sent: Temperature: 8.1°C
# Sent: Temperature: 39.83°C
# Connected to MQTT Broker!
# Sent: Temperature: 38.25°C
# Sent: Temperature: 4.87°C
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!

# %%
import random
import time

from paho.mqtt import client as mqtt_client

broker = 'broker.mqttdashboard.com'
port = 1883
topic1 = "Building/Temperature"
topic2 = "Building/Humidity"

# generate client ID with pub prefix randomly
client_id = f'python-mqtt-{random.randint(0, 1000)}'
username = 'emqx'
password = 'public'

def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n" % rc)

    client = mqtt_client.Client(client_id)
    client.username_pw_set(username, password)
    client.on_connect = on_connect
    client.connect(broker, port)
    return client

def publish(client, num_messages):
    msg_count = 0
    topics = [topic1, topic2]  # List of topics
    while msg_count < num_messages:
        time.sleep(1)
        # Select a random topic from the list
        random_topic = random.choice(topics)
        msg = f"messages: {msg_count}"
        result = client.publish(random_topic, msg)
        # result: [0, 1]
        status = result[0]
        if status == 0:
            print(f"Send `{msg}` to topic `{random_topic}`")
        else:
            print(f"Failed to send message to topic {random_topic}")
        msg_count += 1


def run():
    num_messages = 10  # Change this to the desired number of messages
    client = connect_mqtt()
    client.loop_start()
    publish(client, num_messages)

if __name__ == '__main__':
    run()
# Out:
# Connected to MQTT Broker!
# Send `messages: 0` to topic `Building/Temperature`
# Send `messages: 1` to topic `Building/Humidity`
# Send `messages: 2` to topic `Building/Temperature`
# Send `messages: 3` to topic `Building/Temperature`
# Send `messages: 4` to topic `Building/Humidity`
# Send `messages: 5` to topic `Building/Humidity`
# Send `messages: 6` to topic `Building/Temperature`
# Send `messages: 7` to topic `Building/Temperature`
# Send `messages: 8` to topic `Building/Temperature`
# Send `messages: 9` to topic `Building/Temperature`

# %%
import random
import time
from paho.mqtt import client as mqtt_client

broker = 'broker.hivemq.com'
port = 1883
topic1 = "Building/Temperature"
topic2 = "Building/Humidity"
# generate client ID with pub prefix randomly
client_id = f'python-mqtt-{random.randint(0, 1000)}'
username = 'emqx'
password = 'public'

def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n" % rc)

    client = mqtt_client.Client(client_id)
    client.username_pw_set(username, password)
    client.on_connect = on_connect
    client.connect(broker, port)
    return client

def publish_sensor_data(client, num_messages):
    msg_count = 0
    while msg_count < num_messages:
        time.sleep(1)
        # Generate synthetic temperature and humidity data
        temperature = round(random.uniform(0, 40), 2)
        humidity = round(random.uniform(30, 70), 2)
        
        # Create and publish messages for both topics
        temperature_msg = f"Temperature: {temperature}°C"
        humidity_msg = f"Humidity: {humidity}%"
        
        result1 = client.publish(topic1, temperature_msg)
        result2 = client.publish(topic2, humidity_msg)
        
        # Check and print the status of message publication for both topics
        if result1.rc == mqtt_client.MQTT_ERR_SUCCESS:
            print(f"Sent to {topic1}: {temperature_msg}")
        else:
            print(f"Failed to send to {topic1}")
        
        if result2.rc == mqtt_client.MQTT_ERR_SUCCESS:
            print(f"Sent to {topic2}: {humidity_msg}")
        else:
            print(f"Failed to send to {topic2}")
        
        msg_count += 1

def run():
    num_sensor_readings = 5  # Change this to the desired number of readings
    client = connect_mqtt()
    client.loop_start()
    publish_sensor_data(client, num_sensor_readings)

if __name__ == '__main__':
    run()
# Out:
# Connected to MQTT Broker!
# Sent to Building/Temperature: Temperature: 35.52°C
# Sent to Building/Humidity: Humidity: 69.85%
# Sent to Building/Temperature: Temperature: 0.47°C
# Sent to Building/Humidity: Humidity: 50.26%
# Sent to Building/Temperature: Temperature: 18.42°C
# Sent to Building/Humidity: Humidity: 33.4%
# Sent to Building/Temperature: Temperature: 26.12°C
# Sent to Building/Humidity: Humidity: 43.77%
# Sent to Building/Temperature: Temperature: 3.78°C
# Sent to Building/Humidity: Humidity: 68.98%

# %%
import random
import time

from paho.mqtt import client as mqtt_client

broker = 'broker.mqttdashboard.com'
port = 8884
topic = "Building/Temperature"
# generate client ID with pub prefix randomly
client_id = f'python-mqtt-{random.randint(0, 1000)}'
username = 'emqx'
password = 'staysafe'

def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n" % rc)

    client = mqtt_client.Client(client_id)
    client.username_pw_set(username, password)
    client.on_connect = on_connect
    client.connect(broker, port)
    return client


def publish_temperature(client, num_messages):
    msg_count = 0
    while msg_count < num_messages:
        time.sleep(1)
        # Generate synthetic temperature data between 0°C and 40°C
        temperature = round(random.uniform(0, 40), 2)
        msg = f"Temperature: {temperature}°C"
        result = client.publish(topic, msg)
        status = result[0]
        if status == 0:
            print(f"Sent: {msg}")
        else:
            print(f"Failed to send message")
        msg_count += 1


def run():
    num_temperature_readings = 5  # Change this to the desired number of readings
    client = connect_mqtt()
    client.loop_start()
    publish_temperature(client, num_temperature_readings)


if __name__ == '__main__':
    run()
# Out:
# Connected to MQTT Broker!
# Sent: Temperature: 28.23°C
# Connected to MQTT Broker!
# Sent: Temperature: 29.04°C
# Sent: Temperature: 5.63°C
# Sent: Temperature: 29.0°C
# Connected to MQTT Broker!
# Sent: Temperature: 1.09°C
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!

# %%
import random
import time
from paho.mqtt import client as mqtt_client

broker = 'broker.mqttdashboard.com'
port = 1883
topic = "Building/Temperature"
# generate client ID with pub prefix randomly
client_id = f'python-mqtt-{random.randint(0, 1000)}'
username = 'websocket'
password = 'public1'

def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n" % rc)

    client = mqtt_client.Client(client_id)
    client.username_pw_set(username, password)
    client.on_connect = on_connect
    client.connect(broker, port)
    # Set the connection timeout to 10 seconds (in seconds)
    # client.connect(broker, port, keepalive=10)

    return client

def publish(client):
    msg = "This is a single message"  # Change this to your desired message
    result = client.publish(topic, msg)
    status = result.rc
    if status == mqtt_client.MQTT_ERR_SUCCESS:  # Corrected the reference to MQTT_ERR_SUCCESS
        print(f"Send `{msg}` to topic `{topic}`")
    else:
        print(f"Failed to send message to topic {topic}")

if __name__ == '__main__':
    client = connect_mqtt()
    client.loop_start()
    publish(client)
# Out:
# Send `This is a single message` to topic `Building/Temperature`
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!

# %%
import random
import time

from paho.mqtt import client as mqtt_client

broker = 'broker.mqttdashboard.com'
port = 1883
topic = "Building/Temperature"
# generate client ID with pub prefix randomly
client_id = f'python-mqtt-{random.randint(0, 1000)}'
username = 'websocket'
password = 'public1'

def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n" % rc)

    client = mqtt_client.Client(client_id)
    client.username_pw_set(username, password)
    client.on_connect = on_connect
    client.connect(broker, port)
    return client

def publish(client, num_messages):
    msg_count = 0
    while msg_count < num_messages:
        time.sleep(1)
        msg = f"messages: {msg_count}"
        result = client.publish(topic, msg)
        # result: [0, 1]
        status = result[0]
        if status == 0:
            print(f"Send `{msg}` to topic `{topic}`")
        else:
            print(f"Failed to send message to topic {topic}")
        msg_count += 1

def run():
    num_messages = 6  # Change this to the desired number of messages
    client = connect_mqtt()
    client.loop_start()
    publish(client, num_messages)

if __name__ == '__main__':
    run()
# Out:
# Connected to MQTT Broker!
# Send `messages: 0` to topic `Building/Temperature`
# Send `messages: 1` to topic `Building/Temperature`
# Send `messages: 2` to topic `Building/Temperature`
# Send `messages: 3` to topic `Building/Temperature`
# Send `messages: 4` to topic `Building/Temperature`
# Send `messages: 5` to topic `Building/Temperature`
